# %% [markdown]
# <a href="https://colab.research.google.com/github/nimonit1/Learning-memo/blob/main/Learing-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# リスト初期化

# %% [markdown]
# 直接初期化(C言語風)

# %%
from typing import List

# %%
zero: List[int] = [0,0,0]

# %%
print(zero)
# Out:
# [0, 0, 0]

# %% [markdown]
# 直接初期化

# %%
one: List[int] = [1] * 3

# %%
print(one)
# Out:
# [1, 1, 1]

# %% [markdown]
# リスト内包表現1

# %%
numbers: List[int] = [i for i in range(3)]

# %%
print(numbers)
# Out:
# [0, 1, 2]

# %% [markdown]
# リスト内包表現2

# %%
evens: List[int] = [i * 2 for i in range(3)]

# %%
print(evens)
# Out:
# [0, 2, 4]

# %% [markdown]
# リスト内包表現3

# %%
evens: List[int] = [i for i in range(10) if i % 2 == 0 ]

# %%
print(evens)
# Out:
# [0, 2, 4, 6, 8]
